# %%
! pip install statsmodels --upgrade
# Out:
# Requirement already satisfied: statsmodels in c:\users\rodol\anaconda3\lib\site-packages (0.13.2)
# Collecting statsmodels
#   Downloading statsmodels-0.13.5-cp39-cp39-win_amd64.whl (9.2 MB)
# Requirement already satisfied: numpy>=1.17 in c:\users\rodol\anaconda3\lib\site-packages (from statsmodels) (1.21.5)
# Requirement already satisfied: packaging>=21.3 in c:\users\rodol\anaconda3\lib\site-packages (from statsmodels) (21.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\rodol\anaconda3\lib\site-packages (from statsmodels) (1.4.2)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\rodol\anaconda3\lib\site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: scipy>=1.3 in c:\users\rodol\anaconda3\lib\site-packages (from statsmodels) (1.7.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\rodol\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rodol\anaconda3\lib\site-packages (from pandas>=0.25->statsmodels) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\rodol\anaconda3\lib\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: six in c:\users\rodol\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Installing collected packages: statsmodels
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.13.2
#     Uninstalling statsmodels-0.13.2:
#       Successfully uninstalled statsmodels-0.13.2
# Successfully installed statsmodels-0.13.5

# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Using cached pmdarima-2.0.3-cp39-cp39-win_amd64.whl (572 kB)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\rodol\anaconda3\lib\site-packages (from pmdarima) (0.13.5)
# Requirement already satisfied: pandas>=0.19 in c:\users\rodol\anaconda3\lib\site-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\rodol\anaconda3\lib\site-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\rodol\anaconda3\lib\site-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\rodol\anaconda3\lib\site-packages (from pmdarima) (0.29.28)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\rodol\anaconda3\lib\site-packages (from pmdarima) (61.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\rodol\anaconda3\lib\site-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\rodol\anaconda3\lib\site-packages (from pmdarima) (1.21.5)
# Requirement already satisfied: urllib3 in c:\users\rodol\anaconda3\lib\site-packages (from pmdarima) (1.26.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\rodol\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rodol\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\rodol\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.19->pmdarima) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\rodol\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\rodol\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\rodol\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\rodol\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels>=0.13.2->pmdarima) (3.0.4)
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.0.3

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import pmdarima as pm

# %% [markdown]
# # Analise de series temporais

# %%
n = 100
X = np.linspace(0, 2*np.pi, n)
fs = 1/(X[1]-X[0])
f = fs/20

# %%
def generate_series(x, freq, opt='linear_trend+seasonal'):
    if opt == 'linear_trend':
        fx = x 
    elif opt == 'linear_trend+seasonal':
        fx = x + np.sin(2*np.pi*freq*x)
    elif opt == 'seasonal':
        fx = np.sin(2*np.pi*freq*x)
    else:
        raise ValueError("Unkown opt parameter.")
        
    return fx

# %%
def plot_decompostion(decomposition):
    fig, ax = plt.subplots(figsize=(6,6),nrows=4)
    
    ax[0].plot(decomposition.observed)
    ax[0].set_title("Series")
    
    ax[1].plot(decomposition.trend)
    ax[1].set_title("Trend")
    
    ax[2].plot(decomposition.seasonal)
    ax[2].set_title("Seasonal")
    
    ax[3].plot(decomposition.resid)
    ax[3].set_title("Residue")
    
    plt.tight_layout()
    plt.show()

# %%
n_points_in_period = int(fs/f)
print(f"Numero de pontos por período:{n_points_in_period}")
# Out:
# Numero de pontos por período:20

# %%
series = generate_series(X, f, opt='linear_trend')
decomposition = seasonal_decompose(series, model='additive', 
                                  period= n_points_in_period)
plot_decompostion(decomposition)

# %%
series = generate_series(X, f, opt='linear_trend+seasonal')
decomposition = seasonal_decompose(series, model='additive', 
                                  period= n_points_in_period)
plot_decompostion(decomposition)

# %%
series = generate_series(X, f, opt='seasonal')
decomposition = seasonal_decompose(series, model='additive', 
                                  period= n_points_in_period)
plot_decompostion(decomposition)

# %% [markdown]
# # ACF E PACF

# %%
df = pd.read_csv("https://pycourse.s3.amazonaws.com/monthly_air_passengers.csv", index_col="Month")
df.head()
# Out:
#          #Passengers
# Month
# 1949-01          112
# 1949-02          118
# 1949-03          132
# 1949-04          129
# 1949-05          121

# %%
df.plot(figsize=(10,5));

# %% [markdown]
# # Decomposição

# %%
decomposition = seasonal_decompose(df.values, model='additive', period=12)

# %%
plot_decompostion(decomposition)

# %%
result = adfuller(df)
print(f'p-value:{result[1]}')
# Out:
# p-value:0.9918802434376411

# %%
df_diff = df.diff().dropna()

# %%
result = adfuller(df_diff.dropna())
print(f'p-value:{result[1]}')
# Out:
# p-value:0.0542132902838265

# %%
fig, ax = plt.subplots(ncols=2, figsize=(15,7))
plot_acf(df_diff, ax=ax[0])
plot_pacf(df_diff, ax=ax[1])
plt.show()
# Out:
# 2023-03-21 16:02:36,223 [30940] WARNING  py.warnings:109: [JupyterRequire] C:\Users\rodol\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
n, p = len(df), 0.7
train = df[:int(n*p)]
test = df[int(n*p):]

# %%
model = pm.auto_arima(train,
                     seasonal = True, 
                     m=12, 
                     trace=True,
                     error_actionn='ignore',
                     suppress_warnings=True)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=647.761, Time=0.48 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=650.796, Time=0.03 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=644.203, Time=0.07 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=644.733, Time=0.10 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=645.995, Time=0.04 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=646.172, Time=0.20 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=646.187, Time=0.15 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=644.600, Time=0.11 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=0.65 sec
#  ARIMA(0,1,0)(1,1,0)[12]             : AIC=647.442, Time=0.05 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=646.085, Time=0.12 sec
#  ARIMA(1,1,1)(1,1,0)[12]             : AIC=645.647, Time=0.13 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=644.346, Time=0.08 sec
#  ARIMA(2,1,1)(1,1,0)[12]             : AIC=647.580, Time=0.14 sec
#  ARIMA(1,1,0)(1,1,0)[12] intercept   : AIC=645.940, Time=0.14 sec
#
# Best model:  ARIMA(1,1,0)(1,1,0)[12]
# Total fit time: 2.559 seconds
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  100
# Model:             SARIMAX(1, 1, 0)x(1, 1, 0, 12)   Log Likelihood                -319.101
# Date:                            Tue, 21 Mar 2023   AIC                            644.203
# Time:                                    16:02:40   BIC                            651.601
# Sample:                                01-01-1949   HQIC                           647.182
#                                      - 04-01-1957
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2434      0.097     -2.512      0.012      -0.433      -0.054
# ar.S.L12      -0.2127      0.087     -2.432      0.015      -0.384      -0.041
# sigma2        89.1842     14.080      6.334      0.000      61.587     116.781
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 2.43
# Prob(Q):                              0.97   Prob(JB):                         0.30
# Heteroskedasticity (H):               1.32   Skew:                             0.40
# Prob(H) (two-sided):                  0.46   Kurtosis:                         2.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
forecast = model.predict(n_periods=len(test))

# %%
plt.figure(figsize=(10,5))
plt.plot(np.arange(int(n*p)), train.values, '.-', label='Treino')
plt.plot(np.arange(int(n*p), n), test.values, '.-', label='Teste')
plt.plot(np.arange(int(n*p), n), forecast, '.-', label='Predição')
plt.grid()
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error

# %%
rmse = np.sqrt(mean_squared_error(test, forecast))
print(f'RMSE do modelo no conjunto de teste:{rmse}')
# Out:
# RMSE do modelo no conjunto de teste:26.205870278041857

# %%
model.plot_diagnostics(figsize=(15,8))

# %%
# utilizando o keras: https://keras.io/
import keras
from sklearn.preprocessing import MinMaxScaler

# %%
# extraindo a série (np.array)
series = df.values

# %%
# normalização (max 1 e min 0)
scaler = MinMaxScaler()
series = scaler.fit_transform(series)

# %%
# divisão em treino e teste
n, p = len(df), 0.7
train = series[:int(n*p)]
test = series[int(n*p):]

# %%
# convertendo a série para uma estrutura x_train, y_train
x_train, y_train = train[:-1], train[1:]
x_test, y_test = test[:-1], test[1:]

# %%
# x_train, y_train: primeiras 5 linhas
print(np.c_[x_train, y_train][:5, :])
# Out:
# [[0.01544402 0.02702703]
#  [0.02702703 0.05405405]
#  [0.05405405 0.04826255]
#  [0.04826255 0.03281853]
#  [0.03281853 0.05984556]]

# %%
# construindo modelo
inputs = keras.layers.Input(shape=(1, 1))
lstm_out = keras.layers.LSTM(4)(inputs)
outputs = keras.layers.Dense(1)(lstm_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss="mse")
model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 1, 1)]            0
#
#  lstm_8 (LSTM)               (None, 4)                 96
#
#  dense_8 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 101
# Trainable params: 101
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit no modelo
model.fit(x=x_train, y=y_train, batch_size=1, epochs=25)
# Out:
# Epoch 1/25
# 99/99 [==============================] - 2s 2ms/step - loss: 0.0572
# Epoch 2/25
# 99/99 [==============================] - 0s 2ms/step - loss: 0.0299
# Epoch 3/25
# 99/99 [==============================] - 0s 997us/step - loss: 0.0212
# Epoch 4/25
# 99/99 [==============================] - 0s 2ms/step - loss: 0.0192
# Epoch 5/25
# 99/99 [==============================] - 0s 2ms/step - loss: 0.0182
# Epoch 6/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0173
# Epoch 7/25
# 99/99 [==============================] - 0s 2ms/step - loss: 0.0163
# Epoch 8/25
# 99/99 [==============================] - 0s 2ms/step - loss: 0.0153
# Epoch 9/25
# 99/99 [==============================] - 0s 2ms/step - loss: 0.0144
# Epoch 10/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0134
# Epoch 11/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0122
# Epoch 12/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0112
# Epoch 13/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0101
# Epoch 14/25
# 99/99 [==============================] - 0s 2ms/step - loss: 0.0090
# Epoch 15/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0080
# Epoch 16/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0070
# Epoch 17/25
# 99/99 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 18/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0053
# Epoch 19/25
# 99/99 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 20/25
# 99/99 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 21/25
# 99/99 [==============================] - 0s 2ms/step - loss: 0.0034
# Epoch 22/25
# 99/99 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 23/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 24/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 25/25
# 99/99 [==============================] - 0s 1ms/step - loss: 0.0024

# %%
# previsão
forecast = model.predict(x_test)
# Out:
# 2023-03-21 16:29:09,511 [30940] WARNING  tensorflow:148: [JupyterRequire] 5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001DA515B7D30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 2ms/step

# %%
# valores na escala original
forecast_orig = scaler.inverse_transform(forecast)
y_train_orig = scaler.inverse_transform(y_train)
y_test_orig = scaler.inverse_transform(y_test)

# %%
# plot da predição
n_train, n_test = len(y_train), len(y_test)
plt.figure(figsize=(10, 5))
plt.plot(np.arange(n_train), y_train_orig,'.-', label='Treino')
plt.plot(np.arange(n_train, n_train+n_test), y_test_orig,'.-', label='Teste')
plt.plot(np.arange(n_train, n_train+n_test), forecast_orig,'.-', label='Predição')
plt.grid()
plt.legend()
plt.show()

# %%
# RMSE
rmse = np.sqrt(mean_squared_error(y_test_orig,forecast_orig))
print(f"RMSE do modelo no conjunto de teste: {rmse}")
# Out:
# RMSE do modelo no conjunto de teste: 52.31969013783621

# %%
# adição da sazonalidade como variável exógena
# [s_{t-12}, s_{t-1}] ~ s_t
sz = 12
x_train, y_train = np.c_[train[:-sz], train[sz-1:-1]], train[sz:]
x_test, y_test = np.c_[test[:-sz], test[sz-1:-1]], test

# %%
# contabilização do primeiro ciclo de teste na predição
x_test = np.r_[np.c_[train[-sz:],
                     np.r_[train[-1], test[:sz-1].ravel()]], x_test]

# %%
# construindo modelo
inputs = keras.layers.Input(shape=(2, 1))
lstm_out = keras.layers.LSTM(4)(inputs)
outputs = keras.layers.Dense(1)(lstm_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss="mse")
model.summary()
# Out:
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 2, 1)]            0
#
#  lstm_11 (LSTM)              (None, 4)                 96
#
#  dense_11 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 101
# Trainable params: 101
# Non-trainable params: 0
# _________________________________________________________________

# %%
# previsão
forecast = model.predict(x_test)
# Out:
# 2/2 [==============================] - 0s 16ms/step

# %%
# valores na escala original
forecast_orig = scaler.inverse_transform(forecast)
y_train_orig = scaler.inverse_transform(y_train)
y_test_orig = scaler.inverse_transform(y_test)

# %%
# plot da predição
n_train, n_test = len(y_train), len(y_test)
plt.figure(figsize=(10, 5))
plt.plot(np.arange(n_train), y_train_orig,'.-', label='Treino')
plt.plot(np.arange(n_train, n_train+n_test), y_test_orig,'.-', label='Teste')
plt.plot(np.arange(n_train, n_train+n_test), forecast_orig,'.-', label='Predição')
plt.grid()
plt.legend()
plt.show()

# %%
# RMSE
rmse = np.sqrt(mean_squared_error(y_test_orig,forecast_orig))
print(f"RMSE do modelo no conjunto de teste: {rmse}")
# Out:
# RMSE do modelo no conjunto de teste: 25.991705331104466
