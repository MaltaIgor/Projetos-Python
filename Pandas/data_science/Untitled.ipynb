# %%
import json

# %%
data_dict = json.loads(dad)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# C:\Users\IGOR~1.MAL\AppData\Local\Temp/ipykernel_22776/4049352474.py in <module>
# ----> 1 data_dict = json.loads(dad)
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
# ...

# %%
dad = """{
  "InstanceID": "3d772ae2-e76b-45ac-a04d-69f7afc6b278",
  "datacolumns": [
    {
  "name": "id",
  "dataType": "double",
  "sourceColumn": "id",
  "formatString": "0",
  "sourceProviderType": "double",
  "lineageTag": "94ea0d2d-d718-48b4-9c85-3e77e46e53a8",
  "summarizeBy": "sum",
  "modifiedTime": "2022-04-07T00:18:23.386667",
  "structureModifiedTime": "2021-08-18T01:18:14.48",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:58.106667",
    "refreshedTime": "2022-09-01T11:47:58.106667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-08-18T01:18:14.48"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "id_current_user",
  "dataType": "int64",
  "sourceColumn": "id_current_user",
  "formatString": "0",
  "sourceProviderType": "bigint",
  "lineageTag": "c6438cee-80d3-4e40-8cf8-f01faa15834a",
  "summarizeBy": "sum",
  "modifiedTime": "2021-10-15T12:59:37.536667",
  "structureModifiedTime": "2021-08-18T01:18:14.48",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:57.386667",
    "refreshedTime": "2022-09-01T11:47:57.386667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-08-18T01:18:14.48"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "id_lead",
  "dataType": "string",
  "sourceColumn": "id_lead",
  "lineageTag": "e14a7d4a-c7ab-41a3-9d91-6bac2ef0859f",
  "summarizeBy": "none",
  "modifiedTime": "2021-08-18T01:18:14.48",
  "structureModifiedTime": "2021-08-18T01:18:14.48",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:52.666667",
    "refreshedTime": "2022-09-01T11:48:52.666667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-08-18T01:18:14.48"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "dt_criacao",
  "dataType": "dateTime",
  "sourceColumn": "dt_criacao",
  "formatString": "General Date",
  "lineageTag": "99623847-2234-4c52-864e-c4826db17100",
  "summarizeBy": "none",
  "modifiedTime": "2021-08-18T01:18:14.48",
  "structureModifiedTime": "2021-08-27T12:35:37.58",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:58.223333",
    "refreshedTime": "2022-09-01T11:47:58.223333"
  },
  "variations": [
    {
      "name": "Variation",
      "relationship": "93c3555f-2189-4141-a08b-b9df181d05ce",
      "defaultHierarchy": {
        "table": "LocalDateTable_c9f9b70b-924b-498c-a483-d3295576fabe",
        "hierarchy": "Hierarquia de datas"
      },
      "isDefault": true
    }
  ],
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-08-18T01:18:14.48"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "Campanha",
  "dataType": "string",
  "sourceColumn": "Campanha",
  "lineageTag": "57bfc634-3e55-47f9-a012-32f5ef7fb436",
  "summarizeBy": "none",
  "modifiedTime": "2021-09-02T20:32:15.123333",
  "structureModifiedTime": "2021-08-18T01:18:14.48",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:57.396667",
    "refreshedTime": "2022-09-01T11:47:57.396667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-08-18T01:18:14.48"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "Step",
  "dataType": "string",
  "sourceColumn": "Step",
  "lineageTag": "9123e960-0198-47a3-8df3-2487c6dc6ee8",
  "summarizeBy": "none",
  "modifiedTime": "2021-09-23T14:04:29.07",
  "structureModifiedTime": "2021-08-18T01:18:14.48",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:57.4",
    "refreshedTime": "2022-09-01T11:47:57.4"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-08-18T01:18:14.48"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "Grupo",
  "dataType": "string",
  "sourceColumn": "Grupo",
  "lineageTag": "bad2a296-00db-4677-b917-ccc8cb1577ea",
  "summarizeBy": "none",
  "modifiedTime": "2021-09-02T20:33:29.67",
  "structureModifiedTime": "2021-08-18T01:18:14.48",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:57.4",
    "refreshedTime": "2022-09-01T11:47:57.4"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-08-18T01:18:14.48"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "Tipo do Cliente",
  "dataType": "string",
  "sourceColumn": "Tipo do Cliente",
  "lineageTag": "b26fdc89-fe49-4af1-acce-6544afc584bd",
  "summarizeBy": "none",
  "modifiedTime": "2021-09-02T20:35:55.223333",
  "structureModifiedTime": "2021-08-18T01:18:14.48",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:57.403333",
    "refreshedTime": "2022-09-01T11:47:57.403333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-08-18T01:18:14.48"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "Finalizado Por",
  "dataType": "string",
  "sourceColumn": "Finalizado Por",
  "lineageTag": "bf71650b-7432-4e2c-a2a4-c06d63ef9521",
  "summarizeBy": "none",
  "modifiedTime": "2021-09-02T20:33:00.723333",
  "structureModifiedTime": "2021-08-18T01:18:14.48",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:57.403333",
    "refreshedTime": "2022-09-01T11:47:57.403333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-08-18T01:18:14.48"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "Canal de Atendimento",
  "dataType": "string",
  "sourceColumn": "Canal de Atendimento",
  "lineageTag": "034bab78-19a0-4a46-8ea8-dd3f2f42af93",
  "summarizeBy": "none",
  "modifiedTime": "2021-09-02T20:32:41.136667",
  "structureModifiedTime": "2021-08-18T01:18:14.48",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:57.413333",
    "refreshedTime": "2022-09-01T11:47:57.413333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-08-18T01:18:14.48"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "cidade",
  "dataType": "string",
  "sourceColumn": "cidade",
  "lineageTag": "59868474-5108-4988-aa1e-848996dd9710",
  "summarizeBy": "none",
  "modifiedTime": "2021-08-18T01:18:14.48",
  "structureModifiedTime": "2021-08-18T01:18:14.48",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:57.43",
    "refreshedTime": "2022-09-01T11:47:57.43"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-08-18T01:18:14.48"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "estado",
  "dataType": "string",
  "sourceColumn": "estado",
  "lineageTag": "5db8e547-90a7-47fe-876d-b8c164259e9a",
  "summarizeBy": "none",
  "modifiedTime": "2021-08-18T01:18:14.48",
  "structureModifiedTime": "2021-08-18T01:18:14.48",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:57.43",
    "refreshedTime": "2022-09-01T11:47:57.43"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-08-18T01:18:14.48"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "dt_atualizacao",
  "dataType": "dateTime",
  "sourceColumn": "dt_atualizacao",
  "formatString": "General Date",
  "sourceProviderType": "datetime2",
  "lineageTag": "d44e6b26-813e-4e0b-b8a6-af1d931217f7",
  "summarizeBy": "none",
  "modifiedTime": "2021-09-21T00:23:40.123333",
  "structureModifiedTime": "2021-09-21T00:23:38.646667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:58.316667",
    "refreshedTime": "2022-09-01T11:47:58.316667"
  },
  "variations": [
    {
      "name": "Variation",
      "relationship": "13796d2d-c59b-4376-bd6b-176f29e75da5",
      "defaultHierarchy": {
        "table": "LocalDateTable_00cb91f2-3253-45f1-a830-f2f93de9f469",
        "hierarchy": "Hierarquia de datas"
      },
      "isDefault": true
    }
  ],
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-09-21T00:23:38.646667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "id_operation",
  "dataType": "int64",
  "sourceColumn": "id_operation",
  "formatString": "0",
  "sourceProviderType": "bigint",
  "lineageTag": "3e98cfda-0ae5-42d3-9cf7-fff16f7b8a83",
  "summarizeBy": "none",
  "modifiedTime": "2021-10-15T12:59:38.743333",
  "structureModifiedTime": "2021-09-21T00:23:39.633333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:57.433333",
    "refreshedTime": "2022-09-01T11:47:57.433333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-09-21T00:23:39.633333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "Modalidade",
  "dataType": "string",
  "sourceColumn": "Modalidade",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "8709d463-af5d-445d-9b9f-3308d4d8e0b3",
  "summarizeBy": "none",
  "modifiedTime": "2021-09-22T19:53:53.646667",
  "structureModifiedTime": "2021-09-22T19:52:52.29",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:57.433333",
    "refreshedTime": "2022-09-01T11:47:57.433333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-09-22T19:52:52.293333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "cep",
  "dataType": "string",
  "sourceColumn": "cep",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "341131f5-c494-4e67-ab73-223387230fa7",
  "summarizeBy": "none",
  "modifiedTime": "2021-11-22T21:26:47.896667",
  "structureModifiedTime": "2021-10-06T16:39:45.616667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:58.16",
    "refreshedTime": "2022-09-01T11:47:58.16"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-06T16:39:45.616667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "numero_residencia",
  "dataType": "string",
  "sourceColumn": "numero_residencia",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "1c8c9650-52c5-48cb-aa97-e52f11d0cfaa",
  "summarizeBy": "none",
  "modifiedTime": "2021-10-15T12:03:56.646667",
  "structureModifiedTime": "2021-10-15T12:03:08.526667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:57.46",
    "refreshedTime": "2022-09-01T11:47:57.46"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-15T12:03:08.526667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "viabilidade_estado",
  "dataType": "string",
  "sourceColumn": "viabilidade_estado",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "96970d82-0898-4c9d-8248-0a6aecb0243f",
  "summarizeBy": "none",
  "modifiedTime": "2021-10-15T12:03:56.646667",
  "structureModifiedTime": "2021-10-15T12:03:10.64",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:57.46",
    "refreshedTime": "2022-09-01T11:47:57.46"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-15T12:03:10.64"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "viabilidade_cidade",
  "dataType": "string",
  "sourceColumn": "viabilidade_cidade",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "c717c6ac-6b72-4732-9fd2-e555edbf3f88",
  "summarizeBy": "none",
  "modifiedTime": "2021-10-15T12:03:56.646667",
  "structureModifiedTime": "2021-10-15T12:03:12.98",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:57.48",
    "refreshedTime": "2022-09-01T11:47:57.48"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-15T12:03:12.98"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "viabilidade_numero_residencia",
  "dataType": "string",
  "sourceColumn": "viabilidade_numero_residencia",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "faa81b6e-2bf7-499c-94d4-26b62ff25085",
  "summarizeBy": "none",
  "modifiedTime": "2021-10-15T12:03:56.646667",
  "structureModifiedTime": "2021-10-15T12:03:15.25",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:57.556667",
    "refreshedTime": "2022-09-01T11:47:57.556667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-15T12:03:15.25"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "viabilidade_cep",
  "dataType": "string",
  "sourceColumn": "viabilidade_cep",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "bc2f534c-d17d-4a40-bb8c-24533fd33bce",
  "summarizeBy": "none",
  "modifiedTime": "2021-11-22T21:26:48.356667",
  "structureModifiedTime": "2021-10-15T12:03:17.123333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:58.19",
    "refreshedTime": "2022-09-01T11:47:58.19"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-15T12:03:17.123333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "viabilidade_bairro",
  "dataType": "string",
  "sourceColumn": "viabilidade_bairro",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "5912131b-7048-429d-97e1-e631c07c08b7",
  "summarizeBy": "none",
  "modifiedTime": "2021-10-15T12:03:56.646667",
  "structureModifiedTime": "2021-10-15T12:03:19.34",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:57.873333",
    "refreshedTime": "2022-09-01T11:47:57.873333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-15T12:03:19.34"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "viabilidade_rua",
  "dataType": "string",
  "sourceColumn": "viabilidade_rua",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "15d21107-ae66-4d85-9857-18cc5e4156a9",
  "summarizeBy": "none",
  "modifiedTime": "2021-10-15T12:03:56.646667",
  "structureModifiedTime": "2021-10-15T12:03:21.876667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:59.223333",
    "refreshedTime": "2022-09-01T11:47:59.223333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-15T12:03:21.876667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "migracao_movel",
  "dataType": "string",
  "sourceColumn": "migracao_movel",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "81c4c386-301c-49c4-998a-db7298eeb509",
  "summarizeBy": "none",
  "modifiedTime": "2021-10-15T12:03:56.646667",
  "structureModifiedTime": "2021-10-15T12:03:24.543333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:58.106667",
    "refreshedTime": "2022-09-01T11:47:58.106667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-15T12:03:24.543333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "cpf",
  "dataType": "string",
  "sourceColumn": "cpf",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "a5d808b0-add7-4b00-a141-ba6468fd9aca",
  "summarizeBy": "none",
  "modifiedTime": "2021-10-15T12:03:56.646667",
  "structureModifiedTime": "2021-10-15T12:03:26.773333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.036667",
    "refreshedTime": "2022-09-01T11:48:01.036667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-15T12:03:26.773333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "rg",
  "dataType": "string",
  "sourceColumn": "rg",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "add3e51f-cc4a-4b39-9e3b-aca5e97d9901",
  "summarizeBy": "none",
  "modifiedTime": "2021-10-15T12:03:56.646667",
  "structureModifiedTime": "2021-10-15T12:03:28.64",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:59.343333",
    "refreshedTime": "2022-09-01T11:47:59.343333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-15T12:03:28.64"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "email",
  "dataType": "string",
  "sourceColumn": "email",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "ed8ed807-e579-4dac-8645-960fe1686d54",
  "summarizeBy": "none",
  "modifiedTime": "2021-10-15T12:03:56.646667",
  "structureModifiedTime": "2021-10-15T12:03:31.503333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.343333",
    "refreshedTime": "2022-09-01T11:48:01.343333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-15T12:03:31.503333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "telefone1",
  "dataType": "string",
  "sourceColumn": "telefone1",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "12830e55-bd8c-4812-980d-cd21f6f6e57e",
  "summarizeBy": "none",
  "modifiedTime": "2021-10-15T12:03:56.646667",
  "structureModifiedTime": "2021-10-15T12:03:34.333333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.7",
    "refreshedTime": "2022-09-01T11:48:01.7"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-15T12:03:34.333333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "telefone2",
  "dataType": "string",
  "sourceColumn": "telefone2",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "e5bbcc6e-6859-4285-b705-4c0760217861",
  "summarizeBy": "none",
  "modifiedTime": "2021-10-15T12:03:56.646667",
  "structureModifiedTime": "2021-10-15T12:03:37.076667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:00",
    "refreshedTime": "2022-09-01T11:48:00"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-15T12:03:37.076667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "dia_pagamento",
  "dataType": "int64",
  "sourceColumn": "dia_pagamento",
  "formatString": "0",
  "sourceProviderType": "bigint",
  "lineageTag": "c1e80882-723e-4b91-a6e0-ab64f27cfa86",
  "summarizeBy": "sum",
  "modifiedTime": "2022-04-07T00:18:13.14",
  "structureModifiedTime": "2021-10-15T12:03:40.103333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:58.16",
    "refreshedTime": "2022-09-01T11:47:58.16"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-15T12:03:40.106667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "metodo_pagamento",
  "dataType": "string",
  "sourceColumn": "metodo_pagamento",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "dff6ae15-fd23-4484-a672-31f4f7c5916f",
  "summarizeBy": "none",
  "modifiedTime": "2021-12-01T13:31:15.696667",
  "structureModifiedTime": "2021-10-15T12:03:42.763333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:59.246667",
    "refreshedTime": "2022-09-01T11:47:59.246667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-15T12:03:42.763333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "estado_civil",
  "dataType": "string",
  "sourceColumn": "estado_civil",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "61b2930b-d0dc-43db-97a6-40c246f09414",
  "summarizeBy": "none",
  "modifiedTime": "2021-10-15T12:03:56.646667",
  "structureModifiedTime": "2021-10-15T12:03:45.116667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:57.9",
    "refreshedTime": "2022-09-01T11:47:57.9"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-15T12:03:45.116667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "profissao",
  "dataType": "string",
  "sourceColumn": "profissao",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "12f5e18a-cf7b-40cc-bb7c-c138562acff0",
  "summarizeBy": "none",
  "modifiedTime": "2021-10-15T12:03:56.646667",
  "structureModifiedTime": "2021-10-15T12:03:47.736667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:59.343333",
    "refreshedTime": "2022-09-01T11:47:59.343333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-15T12:03:47.736667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "data_nascimento",
  "dataType": "dateTime",
  "sourceColumn": "data_nascimento",
  "formatString": "Short Date",
  "sourceProviderType": "date",
  "lineageTag": "178a8ed6-3d9d-4042-a3b0-9a4337d74653",
  "summarizeBy": "none",
  "modifiedTime": "2021-11-25T22:28:25.503333",
  "structureModifiedTime": "2021-11-23T20:47:04.936667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:57.906667",
    "refreshedTime": "2022-09-01T11:47:57.906667"
  },
  "variations": [
    {
      "name": "Variation",
      "relationship": "106774f3-20a3-40cb-885c-83908c5ec8eb",
      "defaultHierarchy": {
        "table": "LocalDateTable_62226c83-5dc6-4a51-a4a5-5161471b35d8",
        "hierarchy": "Hierarquia de datas"
      },
      "isDefault": true
    }
  ],
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-15T12:03:50.343333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"FormatString\",\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.873333"
    },
    {
      "name": "UnderlyingDateTimeDataType",
      "value": "Date",
      "modifiedTime": "2021-11-23T20:47:04.256667"
    }
  ]
},
    {
  "name": "nome_mae",
  "dataType": "string",
  "sourceColumn": "nome_mae",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "fd5b518a-45f0-47f1-b941-eb68868ec115",
  "summarizeBy": "none",
  "modifiedTime": "2021-10-15T12:03:56.646667",
  "structureModifiedTime": "2021-10-15T12:03:52.776667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:59.246667",
    "refreshedTime": "2022-09-01T11:47:59.246667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-15T12:03:52.776667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "modalidade_produto",
  "dataType": "string",
  "sourceColumn": "modalidade_produto",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "57ad7b86-c0bc-463a-847b-596fd1d9de49",
  "summarizeBy": "none",
  "modifiedTime": "2021-10-15T12:03:56.646667",
  "structureModifiedTime": "2021-10-15T12:03:54.583333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:58.106667",
    "refreshedTime": "2022-09-01T11:47:58.106667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-15T12:03:54.583333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "nome_cliente",
  "dataType": "string",
  "sourceColumn": "nome_cliente",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "b92ea99b-f031-49a4-a81c-2e91fab82e40",
  "summarizeBy": "none",
  "modifiedTime": "2021-10-19T12:37:22.326667",
  "structureModifiedTime": "2021-10-19T12:37:20.876667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:05.92",
    "refreshedTime": "2022-09-01T11:48:05.92"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-19T12:37:20.88"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "id_blip",
  "dataType": "int64",
  "sourceColumn": "id_blip",
  "formatString": "0",
  "sourceProviderType": "bigint",
  "lineageTag": "52d3c342-9fe4-4787-9ce5-74d4d8bad6f0",
  "summarizeBy": "sum",
  "modifiedTime": "2022-04-07T00:18:14.563333",
  "structureModifiedTime": "2021-10-22T00:34:16.236667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:58.253333",
    "refreshedTime": "2022-09-01T11:47:58.253333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-22T00:34:16.24"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "viabilidade",
  "dataType": "string",
  "sourceColumn": "viabilidade",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "ba230596-aa07-4253-b7af-a996c1c69fe0",
  "summarizeBy": "none",
  "modifiedTime": "2022-04-07T00:18:15.243333",
  "structureModifiedTime": "2021-11-03T20:15:55.766667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:58.223333",
    "refreshedTime": "2022-09-01T11:47:58.223333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-11-03T20:15:55.766667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "first_message",
  "dataType": "string",
  "sourceColumn": "first_message",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "844744b3-ecd3-452b-ab6a-659954d9c1b8",
  "summarizeBy": "none",
  "modifiedTime": "2021-11-10T18:07:39.136667",
  "structureModifiedTime": "2021-11-10T18:07:37.096667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:17.44",
    "refreshedTime": "2022-09-01T11:48:17.44"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-11-10T18:07:37.096667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "nps_data",
  "dataType": "dateTime",
  "sourceColumn": "nps_data",
  "formatString": "General Date",
  "sourceProviderType": "datetime2",
  "lineageTag": "7a545c4b-dc1e-4ec9-8333-d0dd0f301a78",
  "summarizeBy": "none",
  "modifiedTime": "2021-11-19T12:33:49.016667",
  "structureModifiedTime": "2021-11-19T12:33:49.013333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:58.276667",
    "refreshedTime": "2022-09-01T11:47:58.276667"
  },
  "variations": [
    {
      "name": "Variation",
      "relationship": "66105f7a-c195-4265-a3b3-6b9b214cfdd7",
      "defaultHierarchy": {
        "table": "LocalDateTable_eb8d33f1-5dc3-4978-a6ae-8382e39d664d",
        "hierarchy": "Hierarquia de datas"
      },
      "isDefault": true
    }
  ],
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-11-16T14:46:43.39"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "nps_score",
  "dataType": "int64",
  "sourceColumn": "nps_score",
  "formatString": "0",
  "sourceProviderType": "bigint",
  "lineageTag": "c7c02ded-5290-4b74-bc3f-8db53a49b664",
  "summarizeBy": "sum",
  "modifiedTime": "2022-04-07T00:18:15.243333",
  "structureModifiedTime": "2021-11-16T14:46:43.863333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:58.316667",
    "refreshedTime": "2022-09-01T11:47:58.316667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-11-16T14:46:43.863333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "nps_motivo",
  "dataType": "string",
  "sourceColumn": "nps_motivo",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "28ab0f8f-e1c8-4eff-a261-0d0b659cd66e",
  "summarizeBy": "none",
  "modifiedTime": "2021-11-16T14:46:46.516667",
  "structureModifiedTime": "2021-11-16T14:46:44.2",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:59.246667",
    "refreshedTime": "2022-09-01T11:47:59.246667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-11-16T14:46:44.2"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "nps_payload",
  "dataType": "string",
  "sourceColumn": "nps_payload",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "ac3fd4df-0ee3-469d-b540-757c78a7c5ad",
  "summarizeBy": "none",
  "modifiedTime": "2022-04-07T00:18:16.53",
  "structureModifiedTime": "2021-11-16T14:46:44.533333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:59.246667",
    "refreshedTime": "2022-09-01T11:47:59.246667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-11-16T14:46:44.533333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "csat_score",
  "dataType": "int64",
  "sourceColumn": "csat_score",
  "formatString": "0",
  "sourceProviderType": "bigint",
  "lineageTag": "7df1a646-b209-4260-a22c-c9e22f01cedd",
  "summarizeBy": "sum",
  "modifiedTime": "2022-04-07T00:18:16.53",
  "structureModifiedTime": "2021-11-16T14:46:44.86",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:59.343333",
    "refreshedTime": "2022-09-01T11:47:59.343333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-11-16T14:46:44.86"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "csat_tipo",
  "dataType": "string",
  "sourceColumn": "csat_tipo",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "64e47ec4-cf59-4de8-84e0-994800b19ff0",
  "summarizeBy": "none",
  "modifiedTime": "2021-11-16T14:46:46.516667",
  "structureModifiedTime": "2021-11-16T14:46:45.193333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:59.343333",
    "refreshedTime": "2022-09-01T11:47:59.343333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-11-16T14:46:45.193333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "csat_data",
  "dataType": "dateTime",
  "sourceColumn": "csat_data",
  "formatString": "General Date",
  "sourceProviderType": "datetime2",
  "lineageTag": "0202b9e0-668d-4a81-99ec-b15ab36e86b7",
  "summarizeBy": "none",
  "modifiedTime": "2021-11-19T12:33:51.08",
  "structureModifiedTime": "2021-11-19T12:33:51.076667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:59.786667",
    "refreshedTime": "2022-09-01T11:47:59.786667"
  },
  "variations": [
    {
      "name": "Variation",
      "relationship": "fed39800-51f7-4680-b336-93ccfb8ca702",
      "defaultHierarchy": {
        "table": "LocalDateTable_aafe2127-5627-4df2-a4ee-f895e7733d7e",
        "hierarchy": "Hierarquia de datas"
      },
      "isDefault": true
    }
  ],
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-11-16T14:46:45.513333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "csat_motivo",
  "dataType": "string",
  "sourceColumn": "csat_motivo",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "7606c866-cb3f-4b46-a49b-0b03be97a263",
  "summarizeBy": "none",
  "modifiedTime": "2021-11-16T14:46:46.516667",
  "structureModifiedTime": "2021-11-16T14:46:45.833333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:59.786667",
    "refreshedTime": "2022-09-01T11:47:59.786667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-11-16T14:46:45.833333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "csat_satisfacao",
  "dataType": "string",
  "sourceColumn": "csat_satisfacao",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "de16d71e-4206-47c9-a21d-243b69c91cc0",
  "summarizeBy": "none",
  "modifiedTime": "2021-11-30T18:31:50.316667",
  "structureModifiedTime": "2021-11-16T14:46:46.163333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:59.786667",
    "refreshedTime": "2022-09-01T11:47:59.786667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-11-16T14:46:46.163333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "banco_pagamento",
  "dataType": "string",
  "sourceColumn": "banco_pagamento",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "330727dd-99a9-4f59-87c8-ee1cf031a396",
  "summarizeBy": "none",
  "modifiedTime": "2022-01-20T15:14:47.62",
  "structureModifiedTime": "2021-11-23T20:38:58.66",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:59.786667",
    "refreshedTime": "2022-09-01T11:47:59.786667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-11-23T20:38:58.66"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "cluster",
  "dataType": "string",
  "sourceColumn": "cluster",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "5e8bd023-ea06-432b-a0bd-ec677cdb1ee6",
  "summarizeBy": "none",
  "modifiedTime": "2021-11-25T23:24:32.94",
  "structureModifiedTime": "2021-11-25T23:24:32.23",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:59.786667",
    "refreshedTime": "2022-09-01T11:47:59.786667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-11-25T23:24:32.23"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "operacao",
  "dataType": "string",
  "sourceColumn": "operacao",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "2e9d0e03-7800-40e2-8cda-2e7518fd9bd4",
  "summarizeBy": "none",
  "modifiedTime": "2021-12-16T21:10:53.62",
  "structureModifiedTime": "2021-12-16T21:10:51.733333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:47:59.79",
    "refreshedTime": "2022-09-01T11:47:59.79"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-12-16T21:10:51.733333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "telefone_id_lead",
  "dataType": "string",
  "sourceColumn": "telefone_id_lead",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "d9676eb9-b873-4711-bde9-315c91904791",
  "summarizeBy": "none",
  "modifiedTime": "2021-12-20T17:43:28.126667",
  "structureModifiedTime": "2021-12-20T17:43:27.19",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:37.286667",
    "refreshedTime": "2022-09-01T11:48:37.286667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-12-20T17:43:27.193333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "bairro",
  "dataType": "string",
  "sourceColumn": "bairro",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "bb617161-598a-401d-9550-a2be719059e5",
  "summarizeBy": "none",
  "modifiedTime": "2022-01-04T16:37:00.023333",
  "structureModifiedTime": "2022-01-04T16:36:57.496667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:00.153333",
    "refreshedTime": "2022-09-01T11:48:00.153333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-01-04T16:36:57.496667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "rua",
  "dataType": "string",
  "sourceColumn": "rua",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "df15d0e5-bdd2-41e7-b283-dc5d12b08538",
  "summarizeBy": "none",
  "modifiedTime": "2022-01-04T16:37:00.023333",
  "structureModifiedTime": "2022-01-04T16:36:58.98",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:03.476667",
    "refreshedTime": "2022-09-01T11:48:03.476667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-01-04T16:36:58.98"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "origem_first_message",
  "dataType": "string",
  "sourceColumn": "origem_first_message",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "eef4f048-938f-4782-a0e1-d40fb23d82d7",
  "summarizeBy": "none",
  "modifiedTime": "2022-01-24T21:23:24.006667",
  "structureModifiedTime": "2022-01-24T21:23:23.01",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.036667",
    "refreshedTime": "2022-09-01T11:48:01.036667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-01-24T21:23:23.01"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "tempo_primeira_resposta",
  "dataType": "int64",
  "sourceColumn": "tempo_primeira_resposta",
  "formatString": "0",
  "sourceProviderType": "bigint",
  "lineageTag": "416970f7-8230-4d12-99d8-da4cb4f5b358",
  "summarizeBy": "sum",
  "modifiedTime": "2022-04-06T23:24:45.07",
  "structureModifiedTime": "2022-04-06T23:24:33.603333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.036667",
    "refreshedTime": "2022-09-01T11:48:01.036667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-06T23:24:33.606667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "tempo_fila",
  "dataType": "int64",
  "sourceColumn": "tempo_fila",
  "formatString": "0",
  "sourceProviderType": "bigint",
  "lineageTag": "37830daa-8bb7-4b72-895f-8838bdcb13bb",
  "summarizeBy": "sum",
  "modifiedTime": "2022-04-06T23:24:45.07",
  "structureModifiedTime": "2022-04-06T23:24:34.456667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.04",
    "refreshedTime": "2022-09-01T11:48:01.04"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-06T23:24:34.456667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "tempo_medio_resposta",
  "dataType": "int64",
  "sourceColumn": "tempo_medio_resposta",
  "sourceProviderType": "bigint",
  "lineageTag": "687b8d0a-30f2-4d59-a36f-a28787c2a4b5",
  "summarizeBy": "sum",
  "modifiedTime": "2022-04-07T00:18:17.31",
  "structureModifiedTime": "2022-04-06T23:24:35.23",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.106667",
    "refreshedTime": "2022-09-01T11:48:01.106667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-06T23:24:35.23"
    },
    {
      "name": "PBI_FormatHint",
      "value": "{\"isGeneralNumber\":true}",
      "modifiedTime": "2022-04-06T23:24:35.23"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "tempo_espera",
  "dataType": "int64",
  "sourceColumn": "tempo_espera",
  "formatString": "0",
  "sourceProviderType": "bigint",
  "lineageTag": "a48cde6a-5178-427e-a155-d823007b6f9a",
  "summarizeBy": "sum",
  "modifiedTime": "2022-04-06T23:24:45.07",
  "structureModifiedTime": "2022-04-06T23:24:35.926667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.11",
    "refreshedTime": "2022-09-01T11:48:01.11"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-06T23:24:35.926667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "tempo_atendimento",
  "dataType": "int64",
  "sourceColumn": "tempo_atendimento",
  "formatString": "0",
  "sourceProviderType": "bigint",
  "lineageTag": "1149ca18-2ba8-425c-a26b-c6a7cad5b870",
  "summarizeBy": "sum",
  "modifiedTime": "2022-04-06T23:24:45.07",
  "structureModifiedTime": "2022-04-06T23:24:36.8",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.106667",
    "refreshedTime": "2022-09-01T11:48:01.106667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-06T23:24:36.8"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "tempo_primeira_resposta_time",
  "dataType": "dateTime",
  "sourceColumn": "tempo_primeira_resposta_time",
  "formatString": "Long Time",
  "lineageTag": "c4c708b0-f402-441e-b00f-0acd262af04c",
  "summarizeBy": "none",
  "modifiedTime": "2022-04-22T19:18:39.386667",
  "structureModifiedTime": "2022-04-06T23:24:37.64",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.11",
    "refreshedTime": "2022-09-01T11:48:01.11"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-06T23:24:37.643333"
    },
    {
      "name": "UnderlyingDateTimeDataType",
      "value": "Time",
      "modifiedTime": "2022-04-22T19:18:38.483333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "tempo_fila_time",
  "dataType": "dateTime",
  "sourceColumn": "tempo_fila_time",
  "formatString": "Long Time",
  "lineageTag": "a1ed1087-9622-4dff-bb13-46f8bbe9bb42",
  "summarizeBy": "none",
  "modifiedTime": "2022-04-22T19:18:40.02",
  "structureModifiedTime": "2022-04-06T23:24:38.666667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.11",
    "refreshedTime": "2022-09-01T11:48:01.11"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-06T23:24:38.666667"
    },
    {
      "name": "UnderlyingDateTimeDataType",
      "value": "Time",
      "modifiedTime": "2022-04-22T19:18:39.386667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "tempo_medio_resposta_time",
  "dataType": "dateTime",
  "sourceColumn": "tempo_medio_resposta_time",
  "formatString": "Long Time",
  "lineageTag": "a0e635f1-4586-4bc9-ae6f-acfce736904a",
  "summarizeBy": "none",
  "modifiedTime": "2022-04-22T19:18:40.656667",
  "structureModifiedTime": "2022-04-06T23:24:39.333333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.11",
    "refreshedTime": "2022-09-01T11:48:01.11"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-06T23:24:39.333333"
    },
    {
      "name": "UnderlyingDateTimeDataType",
      "value": "Time",
      "modifiedTime": "2022-04-22T19:18:40.02"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "tempo_espera_time",
  "dataType": "dateTime",
  "sourceColumn": "tempo_espera_time",
  "formatString": "Long Time",
  "lineageTag": "3dbaf6b8-e10e-4699-a348-a02d9840a2cf",
  "summarizeBy": "none",
  "modifiedTime": "2022-04-22T19:18:41.263333",
  "structureModifiedTime": "2022-04-06T23:24:40.17",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.113333",
    "refreshedTime": "2022-09-01T11:48:01.113333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-06T23:24:40.17"
    },
    {
      "name": "UnderlyingDateTimeDataType",
      "value": "Time",
      "modifiedTime": "2022-04-22T19:18:40.656667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "tempo_atendimento_time",
  "dataType": "dateTime",
  "sourceColumn": "tempo_atendimento_time",
  "formatString": "Long Time",
  "lineageTag": "0d4efeae-4c81-4378-b08d-3102c4dd879f",
  "summarizeBy": "none",
  "modifiedTime": "2022-04-22T19:18:41.963333",
  "structureModifiedTime": "2022-04-06T23:24:40.833333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.113333",
    "refreshedTime": "2022-09-01T11:48:01.113333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-06T23:24:40.833333"
    },
    {
      "name": "UnderlyingDateTimeDataType",
      "value": "Time",
      "modifiedTime": "2022-04-22T19:18:41.263333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "coringa1",
  "dataType": "string",
  "sourceColumn": "coringa1",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "05e5a8e9-a01d-4c8a-99c8-94e1162ed5d8",
  "summarizeBy": "none",
  "modifiedTime": "2022-04-06T23:24:45.07",
  "structureModifiedTime": "2022-04-06T23:24:41.486667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.113333",
    "refreshedTime": "2022-09-01T11:48:01.113333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-06T23:24:41.486667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "coringa2",
  "dataType": "string",
  "sourceColumn": "coringa2",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "15211810-d4f1-4879-b5d7-aee0518b11f1",
  "summarizeBy": "none",
  "modifiedTime": "2022-04-06T23:24:45.07",
  "structureModifiedTime": "2022-04-06T23:24:42.233333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.113333",
    "refreshedTime": "2022-09-01T11:48:01.113333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-06T23:24:42.233333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "coringa3",
  "dataType": "string",
  "sourceColumn": "coringa3",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "49526c48-ced7-4f38-aefd-7628f6ac652a",
  "summarizeBy": "none",
  "modifiedTime": "2022-04-06T23:24:45.07",
  "structureModifiedTime": "2022-04-06T23:24:42.846667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.113333",
    "refreshedTime": "2022-09-01T11:48:01.113333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-06T23:24:42.846667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "coringa4",
  "dataType": "string",
  "sourceColumn": "coringa4",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "01a0ba22-9216-455b-852c-ae46f3a45ed4",
  "summarizeBy": "none",
  "modifiedTime": "2022-04-06T23:24:45.07",
  "structureModifiedTime": "2022-04-06T23:24:43.486667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.113333",
    "refreshedTime": "2022-09-01T11:48:01.113333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-06T23:24:43.486667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "coringa5",
  "dataType": "decimal",
  "sourceColumn": "coringa5",
  "formatString": "\"R$\"\\ #,0.###############;-\"R$\"\\ #,0.###############;\"R$\"\\ #,0.###############",
  "lineageTag": "ce68fd2e-dba6-4440-97ba-4198b8fa4759",
  "summarizeBy": "sum",
  "modifiedTime": "2022-05-30T22:21:39.846667",
  "structureModifiedTime": "2022-04-06T23:24:44.273333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.343333",
    "refreshedTime": "2022-09-01T11:48:01.343333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-06T23:24:44.273333"
    },
    {
      "name": "PBI_FormatHint",
      "value": "{\"currencyCulture\":\"pt-BR\"}",
      "modifiedTime": "2022-05-30T22:21:39.846667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "id_ticket",
  "dataType": "int64",
  "sourceColumn": "id_ticket",
  "formatString": "0",
  "sourceProviderType": "bigint",
  "lineageTag": "1205e8f3-311d-4046-9ddf-a7baa201e855",
  "summarizeBy": "sum",
  "modifiedTime": "2022-07-05T17:47:38.44",
  "structureModifiedTime": "2022-04-07T00:18:23.386667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:04.513333",
    "refreshedTime": "2022-09-01T11:48:04.513333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-07T00:18:23.386667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "id_channel",
  "dataType": "int64",
  "sourceColumn": "id_channel",
  "formatString": "0",
  "sourceProviderType": "bigint",
  "lineageTag": "4bd7a551-e1fe-45e6-9dc1-2f7b9ff9eb16",
  "summarizeBy": "sum",
  "modifiedTime": "2022-04-07T00:18:29.31",
  "structureModifiedTime": "2022-04-07T00:18:24.086667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.113333",
    "refreshedTime": "2022-09-01T11:48:01.113333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-07T00:18:24.086667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "data",
  "dataType": "dateTime",
  "sourceColumn": "data",
  "formatString": "Long Date",
  "sourceProviderType": "date",
  "lineageTag": "97ac61ff-5563-48b3-83d8-b876f76aa679",
  "summarizeBy": "none",
  "modifiedTime": "2022-04-07T00:18:29.31",
  "structureModifiedTime": "2022-04-07T00:18:24.866667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.343333",
    "refreshedTime": "2022-09-01T11:48:01.343333"
  },
  "variations": [
    {
      "name": "Variation",
      "relationship": "a99f25d1-26ff-42cb-b884-5ba22fd1107c",
      "defaultHierarchy": {
        "table": "LocalDateTable_0c3ff443-1d65-47fe-8b17-021013f4a442",
        "hierarchy": "Hierarquia de datas"
      },
      "isDefault": true
    }
  ],
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-07T00:18:24.87"
    },
    {
      "name": "UnderlyingDateTimeDataType",
      "value": "Date",
      "modifiedTime": "2022-04-07T00:18:24.87"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "hora_fechada",
  "dataType": "int64",
  "sourceColumn": "hora_fechada",
  "formatString": "0",
  "sourceProviderType": "bigint",
  "lineageTag": "f74ea653-35d9-47fc-bfa5-0e5d039b9483",
  "summarizeBy": "none",
  "modifiedTime": "2022-06-02T18:42:54.23",
  "structureModifiedTime": "2022-04-07T00:18:25.74",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.343333",
    "refreshedTime": "2022-09-01T11:48:01.343333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-07T00:18:25.74"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "team",
  "dataType": "string",
  "sourceColumn": "team",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "57dc8de9-86f1-4345-ba7b-f74ac15000ea",
  "summarizeBy": "none",
  "modifiedTime": "2022-04-07T00:18:29.31",
  "structureModifiedTime": "2022-04-07T00:18:26.443333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.343333",
    "refreshedTime": "2022-09-01T11:48:01.343333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-07T00:18:26.443333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "nps_satisfacao",
  "dataType": "string",
  "sourceColumn": "nps_satisfacao",
  "sourceProviderType": "nvarchar(max)",
  "lineageTag": "23605755-4d37-4dc9-b868-161375d9c29f",
  "summarizeBy": "none",
  "modifiedTime": "2022-04-07T00:18:29.31",
  "structureModifiedTime": "2022-04-07T00:18:27.17",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.346667",
    "refreshedTime": "2022-09-01T11:48:01.346667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-07T00:18:27.17"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "tem_nps",
  "dataType": "int64",
  "sourceColumn": "tem_nps",
  "formatString": "0",
  "sourceProviderType": "bigint",
  "lineageTag": "8d1fb374-afde-4ef1-aa06-0e8735611f99",
  "summarizeBy": "sum",
  "modifiedTime": "2022-04-07T00:18:29.31",
  "structureModifiedTime": "2022-04-07T00:18:27.906667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.346667",
    "refreshedTime": "2022-09-01T11:48:01.346667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-07T00:18:27.906667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "tem_csat",
  "dataType": "int64",
  "sourceColumn": "tem_csat",
  "formatString": "0",
  "sourceProviderType": "bigint",
  "lineageTag": "68c21d15-1a02-4fb3-8654-9f49f5553936",
  "summarizeBy": "sum",
  "modifiedTime": "2022-04-07T00:18:29.31",
  "structureModifiedTime": "2022-04-07T00:18:28.526667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.346667",
    "refreshedTime": "2022-09-01T11:48:01.346667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-07T00:18:28.526667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "duracao_chamada",
  "dataType": "string",
  "sourceColumn": "duracao_chamada",
  "lineageTag": "5f95d6ad-8f57-4039-a1fb-781d8c3fa77d",
  "summarizeBy": "none",
  "modifiedTime": "2022-05-25T11:49:48.273333",
  "structureModifiedTime": "2022-05-25T11:49:45.593333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.346667",
    "refreshedTime": "2022-09-01T11:48:01.346667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-05-25T11:49:45.593333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "cod_mailing",
  "dataType": "string",
  "sourceColumn": "cod_mailing",
  "lineageTag": "424e9e90-353e-4572-8b4d-a96ab1c12037",
  "summarizeBy": "none",
  "modifiedTime": "2022-05-25T11:49:48.273333",
  "structureModifiedTime": "2022-05-25T11:49:46.366667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.393333",
    "refreshedTime": "2022-09-01T11:48:01.393333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-05-25T11:49:46.366667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "produto",
  "dataType": "string",
  "sourceColumn": "produto",
  "lineageTag": "1e6d3f9a-77a1-493b-8e6e-8507c7d31189",
  "summarizeBy": "none",
  "modifiedTime": "2022-05-30T17:50:10.733333",
  "structureModifiedTime": "2022-05-30T17:50:09.33",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.396667",
    "refreshedTime": "2022-09-01T11:48:01.396667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-05-30T17:50:09.333333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "genero",
  "dataType": "string",
  "sourceColumn": "genero",
  "lineageTag": "84001f61-4fd9-4d41-8aca-397aa9f342ef",
  "summarizeBy": "none",
  "modifiedTime": "2022-05-30T17:50:10.733333",
  "structureModifiedTime": "2022-05-30T17:50:10.073333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.396667",
    "refreshedTime": "2022-09-01T11:48:01.396667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-05-30T17:50:10.073333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "router_name",
  "dataType": "string",
  "sourceColumn": "router_name",
  "lineageTag": "874a4f3c-31a2-4fd5-b52e-3738171aad61",
  "summarizeBy": "none",
  "modifiedTime": "2022-06-02T20:39:19.12",
  "structureModifiedTime": "2022-06-02T20:39:16.87",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.396667",
    "refreshedTime": "2022-09-01T11:48:01.396667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-06-02T20:39:16.87"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "witcom_id_router",
  "dataType": "string",
  "sourceColumn": "witcom_id_router",
  "lineageTag": "4cae0dbd-b659-4d52-9250-b32acaa071a2",
  "summarizeBy": "none",
  "modifiedTime": "2022-06-02T20:39:19.12",
  "structureModifiedTime": "2022-06-02T20:39:17.716667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.396667",
    "refreshedTime": "2022-09-01T11:48:01.396667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-06-02T20:39:17.72"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "router_image",
  "dataType": "string",
  "sourceColumn": "router_image",
  "lineageTag": "343b5a3b-b367-4baf-b413-807dcb5bc4d8",
  "summarizeBy": "none",
  "modifiedTime": "2022-06-02T20:39:19.12",
  "structureModifiedTime": "2022-06-02T20:39:18.316667",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.4",
    "refreshedTime": "2022-09-01T11:48:01.4"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-06-02T20:39:18.316667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "index_push",
  "dataType": "string",
  "sourceColumn": "index_push",
  "lineageTag": "48297368-2356-4881-8ab4-bf585a6f2852",
  "summarizeBy": "none",
  "modifiedTime": "2022-06-12T16:58:25.433333",
  "structureModifiedTime": "2022-06-12T16:58:24.603333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.48",
    "refreshedTime": "2022-09-01T11:48:01.48"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-06-12T16:58:24.606667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "csat_feedback",
  "dataType": "string",
  "sourceColumn": "csat_feedback",
  "lineageTag": "3d6d8edf-27c5-42bf-b8f0-85042b6a2cab",
  "summarizeBy": "none",
  "modifiedTime": "2022-06-15T19:19:18.866667",
  "structureModifiedTime": "2022-06-15T19:19:17.95",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.503333",
    "refreshedTime": "2022-09-01T11:48:01.503333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-06-15T19:19:17.95"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "name": "complemento_endereco",
  "dataType": "string",
  "sourceColumn": "complemento_endereco",
  "lineageTag": "5e681773-1d75-4807-b204-3df7ee92cb57",
  "summarizeBy": "none",
  "modifiedTime": "2022-08-23T18:46:35.623333",
  "structureModifiedTime": "2022-08-23T18:46:32.98",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:04.37",
    "refreshedTime": "2022-09-01T11:48:04.37"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-08-23T18:46:32.99"
    }
  ]
},
    {
  "name": "origem_dados",
  "dataType": "string",
  "sourceColumn": "origem_dados",
  "lineageTag": "d3d191f9-5ebf-45c6-98b0-d4fd67ad086a",
  "summarizeBy": "none",
  "modifiedTime": "2022-08-24T16:22:43.666667",
  "structureModifiedTime": "2022-08-24T16:22:42.303333",
  "refreshedTime": "1699-12-31T00:00:00",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:01.703333",
    "refreshedTime": "2022-09-01T11:48:01.703333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-08-24T16:22:42.303333"
    }
  ]
}
  ],
  "calculatedcolumns": [
    {
  "type": "calculated",
  "name": "_id_data",
  "dataType": "string",
  "isDataTypeInferred": true,
  "expression": "[id_ticket] & DATE(YEAR('WIT Engajados Vendas e Não Vendas'[dt_criacao]), MONTH('WIT Engajados Vendas e Não Vendas'[dt_criacao]), DAY('WIT Engajados Vendas e Não Vendas'[dt_criacao]))",
  "lineageTag": "b9f65614-a211-482c-9d02-e848c934b131",
  "summarizeBy": "none",
  "modifiedTime": "2022-09-01T11:48:37.646667",
  "structureModifiedTime": "2021-08-18T01:26:34.15",
  "refreshedTime": "2022-09-01T11:48:37.646667",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:49.696667",
    "refreshedTime": "2022-09-01T11:48:49.696667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-08-18T01:26:34.566667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "_id_unico_operacao",
  "dataType": "string",
  "isDataTypeInferred": true,
  "expression": "FORMAT('WIT Engajados Vendas e Não Vendas'[_Data], \"YYYY-MM-DD\") &\"-\"& 'WIT Engajados Vendas e Não Vendas'[id_operation]",
  "lineageTag": "7253e5be-9688-4147-8aed-23f8605612a5",
  "summarizeBy": "none",
  "modifiedTime": "2022-09-01T11:48:32.276667",
  "structureModifiedTime": "2021-09-02T20:59:53.536667",
  "refreshedTime": "2022-09-01T11:48:32.276667",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:38.683333",
    "refreshedTime": "2022-09-01T11:48:38.683333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-09-02T20:59:53.886667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "_id_ticket",
  "dataType": "string",
  "isDataTypeInferred": true,
  "expression": "'WIT Engajados Vendas e Não Vendas'[_Data] & 'WIT Engajados Vendas e Não Vendas'[id_ticket] & 'WIT Engajados Vendas e Não Vendas'[Finalizado Por]",
  "lineageTag": "450d00db-d469-4704-b81e-2545166dc943",
  "summarizeBy": "none",
  "modifiedTime": "2022-09-01T11:48:37.356667",
  "structureModifiedTime": "2021-09-22T20:29:28.946667",
  "refreshedTime": "2022-09-01T11:48:37.356667",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:55.623333",
    "refreshedTime": "2022-09-01T11:48:55.623333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-09-22T20:29:30.566667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "Remover \"Testes\" do cálculo",
  "dataType": "string",
  "isDataTypeInferred": true,
  "expression": "IF(\n    CONTAINSSTRING(UPPER('WIT Engajados Vendas e Não Vendas'[nome_cliente]), \"TESTE\")\n    || CONTAINSSTRING(UPPER('WIT Engajados Vendas e Não Vendas'[Step]), \"TESTE\")\n    || 'WIT Engajados Vendas e Não Vendas'[Grupo] = \"TESTE\"\n    || CONTAINSSTRING('WIT Engajados Vendas e Não Vendas'[id_lead], \"3190763525\"),\n    \"Não\",\n    \"Sim\"\n)",
  "lineageTag": "c8f39a7c-c1ed-4c80-90a9-ba1bf765c8fa",
  "summarizeBy": "none",
  "modifiedTime": "2022-09-01T11:49:12.16",
  "structureModifiedTime": "2021-09-28T16:53:16.133333",
  "refreshedTime": "2022-09-01T11:49:12.16",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:49:12.166667",
    "refreshedTime": "2022-09-01T11:49:12.166667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-09-28T16:53:18.62"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "_id_ticket_operation_data",
  "dataType": "string",
  "isDataTypeInferred": true,
  "expression": "FORMAT('WIT Engajados Vendas e Não Vendas'[dt_atualizacao], \"YYYY-MM-DD\") &\"-\"& 'WIT Engajados Vendas e Não Vendas'[id_operation]",
  "lineageTag": "1f140598-b2b2-4ea7-8cc5-41038e2b4bfb",
  "summarizeBy": "none",
  "modifiedTime": "2022-09-01T11:48:15.953333",
  "structureModifiedTime": "2021-09-29T11:24:38.456667",
  "refreshedTime": "2022-09-01T11:48:15.953333",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:16.096667",
    "refreshedTime": "2022-09-01T11:48:16.096667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-09-29T11:24:39.46"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "_id_ticket_ath",
  "dataType": "string",
  "isDataTypeInferred": true,
  "expression": "'WIT Engajados Vendas e Não Vendas'[id_ticket] & UPPER('WIT Engajados Vendas e Não Vendas'[Finalizado Por])",
  "lineageTag": "d697143c-4f7b-4f8b-ad0f-50421f47ad12",
  "summarizeBy": "none",
  "modifiedTime": "2022-09-01T11:48:18.076667",
  "structureModifiedTime": "2021-10-06T13:21:58.406667",
  "refreshedTime": "2022-09-01T11:48:18.076667",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:31.456667",
    "refreshedTime": "2022-09-01T11:48:31.456667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-06T13:21:59.393333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "idade cliente",
  "dataType": "int64",
  "isDataTypeInferred": true,
  "expression": "\nvar x = IF('WIT Engajados Vendas e Não Vendas'[data_nascimento] <> BLANK(), DATEDIFF('WIT Engajados Vendas e Não Vendas'[data_nascimento], NOW(), YEAR), 0)\nreturn IF(x <= 0, BLANK(), IF(x >= 130, BLANK(), x))",
  "formatString": "0",
  "lineageTag": "ecb28cf5-36b2-4640-82ed-4bbd0f70f9a7",
  "summarizeBy": "sum",
  "modifiedTime": "2022-09-01T11:48:04.833333",
  "structureModifiedTime": "2021-10-15T15:05:08.546667",
  "refreshedTime": "2022-09-01T20:31:04.676667",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:10.096667",
    "refreshedTime": "2022-09-01T20:31:04.676667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-15T15:02:23.483333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "Estado_Real",
  "dataType": "string",
  "isDataTypeInferred": true,
  "expression": "IF('WIT Engajados Vendas e Não Vendas'[viabilidade_estado] = BLANK(), 'WIT Engajados Vendas e Não Vendas'[estado], 'WIT Engajados Vendas e Não Vendas'[viabilidade_estado])",
  "lineageTag": "8f3c63c1-4930-47bc-9d20-ce9cc23eaf98",
  "summarizeBy": "none",
  "modifiedTime": "2022-09-01T11:48:04.83",
  "structureModifiedTime": "2021-10-26T20:12:09.876667",
  "refreshedTime": "2022-09-01T11:48:04.83",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:07.18",
    "refreshedTime": "2022-09-01T11:48:07.18"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-26T20:12:11.096667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "Cidade_Real",
  "dataType": "string",
  "isDataTypeInferred": true,
  "expression": "IF('WIT Engajados Vendas e Não Vendas'[viabilidade_cidade] = BLANK(), 'WIT Engajados Vendas e Não Vendas'[cidade], 'WIT Engajados Vendas e Não Vendas'[viabilidade_cidade])",
  "lineageTag": "a9e594bc-eadf-494e-8e22-92c34a396e7c",
  "summarizeBy": "none",
  "modifiedTime": "2022-09-01T11:48:04.97",
  "structureModifiedTime": "2021-10-26T20:14:16.743333",
  "refreshedTime": "2022-09-01T11:48:04.97",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:07.216667",
    "refreshedTime": "2022-09-01T11:48:07.216667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-26T20:14:19.58"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "CEP_Real",
  "dataType": "string",
  "isDataTypeInferred": true,
  "expression": "IF('WIT Engajados Vendas e Não Vendas'[viabilidade_cep] = BLANK(), 'WIT Engajados Vendas e Não Vendas'[cep], 'WIT Engajados Vendas e Não Vendas'[viabilidade_cep])",
  "lineageTag": "256bc4eb-6de8-44d5-aad3-6405510c22af",
  "summarizeBy": "none",
  "modifiedTime": "2022-09-01T11:48:05.803333",
  "structureModifiedTime": "2021-10-26T20:16:24.003333",
  "refreshedTime": "2022-09-01T11:48:05.803333",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:08.296667",
    "refreshedTime": "2022-09-01T11:48:08.296667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-10-26T20:16:26.03"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "Criado após inicio da operação",
  "dataType": "int64",
  "isDataTypeInferred": true,
  "expression": "\nIF(\n   'WIT Engajados Vendas e Não Vendas'[dt_criacao] >= LOOKUPVALUE(\n        'auxiliar operations'[dt_inicio],\n        'auxiliar operations'[id],\n    'WIT Engajados Vendas e Não Vendas'[id_operation]\n    ),\n   1,\n   0\n)\n//FIRSTNONBLANK('auxiliar operations'[dt_inicio], SELECTEDVALUE('WIT Engajados Vendas e Não Vendas'[id_operation]) = SELECTEDVALUE('auxiliar operations'[id]))",
  "formatString": "0",
  "lineageTag": "0b5d2bf9-a29e-4d23-9718-d8378f70a770",
  "summarizeBy": "sum",
  "modifiedTime": "2022-09-01T11:48:08.83",
  "structureModifiedTime": "2022-03-03T20:03:56.99",
  "refreshedTime": "2022-09-01T11:48:08.83",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:10.913333",
    "refreshedTime": "2022-09-01T11:48:10.913333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-11-04T19:01:39.376667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "É SAC?",
  "dataType": "string",
  "isDataTypeInferred": true,
  "expression": "IF([id_operation] = 90, \"Sim\", \"Não\")\n/*IF(\n    ('WIT Engajados Vendas e Não Vendas'[id_operation] in {67, 90}) && \n    UPPER('WIT Engajados Vendas e Não Vendas'[Step]) = \"ASKCANIHELP\" &&\n    'WIT Engajados Vendas e Não Vendas'[dt_criacao] >= DATEVALUE(\"2021-11-01 00:00:00\"), \n    \"Sim\", \n    \"Não\"\n)*//*\nvar x = LOOKUPVALUE('core_attendance vw_tickets_sac'[id_ticket],'core_attendance vw_tickets_sac'[id_ticket], 'WIT Engajados Vendas e Não Vendas'[id_ticket])\nreturn IF(\n    x <> BLANK() && \n    'WIT Engajados Vendas e Não Vendas'[id_operation] in {67, 90} && \n    [dt_criacao] < DATE(2022,04,29),\n    \"Sim\", \n    \"Não\"\n)*/",
  "lineageTag": "18566b4f-3eb5-46db-b061-495a81fa133d",
  "summarizeBy": "none",
  "modifiedTime": "2022-09-01T11:48:04.83",
  "structureModifiedTime": "2021-11-10T12:13:48.853333",
  "refreshedTime": "2022-09-01T11:48:04.83",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:06.946667",
    "refreshedTime": "2022-09-01T11:48:06.946667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-11-10T12:13:51.02"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "Identificação Origem",
  "dataType": "string",
  "isDataTypeInferred": true,
  "expression": "IF(\n        [id_operation] in {67, 90} &&\n        ((CONTAINSSTRING(LOWER([first_message]), \"olá\") || CONTAINSSTRING(LOWER([first_message]), \"ola\"))  ||\n        [Campanha] in {\"landingPage\", \"master_vendas_atendimento\",\"master_whatsapp_lp\"}),\n        \"LP Mundiale\",\n        IF(\n            CONTAINSSTRING(LOWER([first_message]), \"olá 😀\"),\n            \"Página Oficial\",\n            IF(\n                CONTAINSSTRING(LOWER([first_message]), \"olá 😉\"),\n                \"LP Mundiale\",\n                IF(\n                    CONTAINSSTRING(LOWER([first_message]), \"olá 😁\"),\n                    \"Facebook\",\n                    IF(\n                        CONTAINSSTRING(LOWER([first_message]), \"olá 🙂\"),\n                        \"Instagram\",\n                        \"Não identificado\"/*IF(\n                            CONTAINSSTRING(LOWER([first_message]), \"olá\"),\n                            \"Página Oficial\",\n                            \"Não identificado\"\n                        )*/\n                    )\n                )\n            )\n        )\n    )",
  "lineageTag": "d532a653-e97e-46ae-996d-d02257a854d2",
  "summarizeBy": "none",
  "modifiedTime": "2022-09-01T11:49:06.633333",
  "structureModifiedTime": "2021-11-11T19:15:54.886667",
  "refreshedTime": "2022-09-01T11:49:06.633333",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:49:06.643333",
    "refreshedTime": "2022-09-01T11:49:06.643333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-11-11T19:15:55.676667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "Qtd AskCustomerProfile",
  "dataType": "int64",
  "isDataTypeInferred": true,
  "expression": "/*CALCULATE(\n    SUM('core_attendance vw_qtd_repostas_incorretas_askCustomerProfile'[Tentativas Step askCustomerProfile]),\n    FILTER(\n        'core_attendance vw_qtd_repostas_incorretas_askCustomerProfile',\n        'core_attendance vw_qtd_repostas_incorretas_askCustomerProfile'[id_ticket] = [id_ticket]\n    )\n)*/\n/*LOOKUPVALUE(\n    'core_attendance vw_qtd_repostas_incorretas_askCustomerProfile'[Tentativas Step askCustomerProfile], \n    'core_attendance vw_qtd_repostas_incorretas_askCustomerProfile'[id_ticket], \n    'WIT Engajados Vendas e Não Vendas'[id]\n)*/",
  "formatString": "0",
  "lineageTag": "7d38f78c-6337-4c3a-ae5a-436dc20ee1ba",
  "summarizeBy": "sum",
  "modifiedTime": "2022-09-01T11:48:01.703333",
  "structureModifiedTime": "2021-11-26T14:34:37.086667",
  "refreshedTime": "2022-09-01T11:48:01.703333",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:06.976667",
    "refreshedTime": "2022-09-01T11:48:06.976667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2021-11-26T14:34:38.463333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "ID Push Especial",
  "dataType": "int64",
  "isDataTypeInferred": true,
  "expression": "\n/*var x = CALCULATE\n(\n    FIRSTNONBLANK(\n        'sms_actions vw_sms_actions'[index],\n        1\n    ),\n    FILTER(\n        'sms_actions vw_sms_actions',\n        IFERROR(VALUE([telefone_id_lead]), BLANK()) = 'sms_actions vw_sms_actions'[telephone] &&\n        (\n            [dt_atualizacao] >= 'sms_actions vw_sms_actions'[dt_disparo]  &&\n            [dt_atualizacao] <= 'sms_actions vw_sms_actions'[dt_disparo]+3\n        ) && \n        [id_operation] = 'sms_actions vw_sms_actions'[id_operacao] &&\n        'sms_actions vw_sms_actions'[foi_entregue] = 1 && \n        'sms_actions vw_sms_actions'[pode engajar?] = 1\n    )\n)\n\nreturn IF(x = BLANK(), -1, x)*/",
  "formatString": "0",
  "lineageTag": "1be62f06-ea20-43b7-806b-5dac438ebefe",
  "summarizeBy": "sum",
  "modifiedTime": "2022-09-01T11:48:01.4",
  "structureModifiedTime": "2022-03-18T04:30:13.883333",
  "refreshedTime": "2022-09-01T11:48:01.4",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:05.956667",
    "refreshedTime": "2022-09-01T11:48:05.956667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-03-18T04:30:14.893333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "Hora",
  "dataType": "string",
  "isDataTypeInferred": true,
  "expression": "FORMAT([dt_criacao], \"hh\") & \":00\"",
  "lineageTag": "cdd7a52f-212a-40d9-a370-588dfab9c3cd",
  "summarizeBy": "none",
  "modifiedTime": "2022-09-01T11:48:09.113333",
  "structureModifiedTime": "2022-03-25T02:55:38.433333",
  "refreshedTime": "2022-09-01T11:48:09.113333",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:10.913333",
    "refreshedTime": "2022-09-01T11:48:10.913333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-03-25T02:55:39.466667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "É engajado produtivo?",
  "dataType": "string",
  "isDataTypeInferred": true,
  "expression": "IF([Grupo] IN {\"VENDA\", \"RECUSA\", \"ABANDONO\"}, \"Sim\", \"Não\")",
  "lineageTag": "e0768b1f-9848-4dee-9290-ae9a9907b85f",
  "summarizeBy": "none",
  "modifiedTime": "2022-09-01T11:48:04.89",
  "structureModifiedTime": "2022-04-02T00:34:44.626667",
  "refreshedTime": "2022-09-01T11:48:04.89",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:10.176667",
    "refreshedTime": "2022-09-01T11:48:10.176667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-02T00:34:45.503333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "_Data",
  "dataType": "dateTime",
  "isDataTypeInferred": true,
  "expression": "DATE(YEAR('WIT Engajados Vendas e Não Vendas'[dt_criacao]), MONTH('WIT Engajados Vendas e Não Vendas'[dt_criacao]), DAY('WIT Engajados Vendas e Não Vendas'[dt_criacao]))",
  "lineageTag": "32f1995f-1c37-4b44-9b2e-2cdf417bd183",
  "summarizeBy": "none",
  "modifiedTime": "2022-09-01T11:48:08.363333",
  "structureModifiedTime": "2022-04-07T00:26:16.37",
  "refreshedTime": "2022-09-01T11:48:08.363333",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:10.856667",
    "refreshedTime": "2022-09-01T11:48:10.856667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-07T00:27:18.41"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "_id_wit_user",
  "dataType": "string",
  "isDataTypeInferred": true,
  "expression": "[id_current_user] & [_Data]",
  "lineageTag": "8f6b5575-aafb-4a05-8c61-d13a16cc3a68",
  "summarizeBy": "none",
  "modifiedTime": "2022-09-01T11:48:25.85",
  "structureModifiedTime": "2022-04-14T20:51:47.993333",
  "refreshedTime": "2022-09-01T11:48:25.85",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:25.99",
    "refreshedTime": "2022-09-01T11:48:25.99"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-04-14T20:51:48.846667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "viabilidade_tratado",
  "dataType": "string",
  "isDataTypeInferred": true,
  "expression": "if('WIT Engajados Vendas e Não Vendas'[viabilidade] = blank(),\n                        \"Não Consultou\",\n                        if('WIT Engajados Vendas e Não Vendas'[viabilidade]=\"0\",\n                            \"Sem Viabilidade\",\n                            if('WIT Engajados Vendas e Não Vendas'[viabilidade]=\"1\",\n                                \"Tem Viabilidade\",\n                                blank()\n                                )\n                        )\n)\n",
  "lineageTag": "b3add67a-327c-454a-93db-bd76033cff4c",
  "summarizeBy": "none",
  "modifiedTime": "2022-09-01T11:48:05.493333",
  "structureModifiedTime": "2022-06-13T17:46:45.126667",
  "refreshedTime": "2022-09-01T11:48:05.493333",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:07.2",
    "refreshedTime": "2022-09-01T11:48:07.2"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-06-13T17:46:46.153333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "_id_dt_wit",
  "dataType": "string",
  "isDataTypeInferred": true,
  "expression": "'WIT Engajados Vendas e Não Vendas'[dt_criacao].[Ano] & 'WIT Engajados Vendas e Não Vendas'[dt_criacao].[MonthNo] & 'WIT Engajados Vendas e Não Vendas'[dt_criacao].[Dia] & 'WIT Engajados Vendas e Não Vendas'[id_current_user]",
  "lineageTag": "d7235cf8-55b0-4e7d-b18a-46b77a01cf88",
  "summarizeBy": "none",
  "modifiedTime": "2022-09-01T11:48:32.086667",
  "structureModifiedTime": "2022-06-14T20:22:35.323333",
  "refreshedTime": "2022-09-01T11:48:32.086667",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:38.686667",
    "refreshedTime": "2022-09-01T11:48:38.686667"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-06-14T20:22:36.16"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "teste_viabilidade",
  "dataType": "string",
  "isDataTypeInferred": true,
  "expression": "\nif(\n    'WIT Engajados Vendas e Não Vendas'[viabilidade] = \"0\",\n    \"NÃO POSSUI VIABILIDADE\",\n    if('WIT Engajados Vendas e Não Vendas'[viabilidade]=\"1\",\n        \"POSSUI VIABILIDADE\",\n        \"NÃO CONSULTOU VIABILIDADE\"\n    )\n)",
  "lineageTag": "fdecd069-1d58-4b4d-b166-2e8dbd70fa17",
  "summarizeBy": "none",
  "modifiedTime": "2022-09-01T11:48:06.25",
  "structureModifiedTime": "2022-06-24T18:32:25.28",
  "refreshedTime": "2022-09-01T11:48:06.25",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:10.07",
    "refreshedTime": "2022-09-01T11:48:10.07"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-06-24T18:32:26.136667"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "MODALIDADE NOVO",
  "dataType": "string",
  "isDataTypeInferred": true,
  "expression": "IF('WIT Engajados Vendas e Não Vendas'[Modalidade]=\"BASE\", \"BASE\", IF('WIT Engajados Vendas e Não Vendas'[Modalidade]=\"PROSPECT\",\"PROSPECT\",\"VAZIO\"))",
  "lineageTag": "616089a8-c33e-46af-9427-f62e7b81bd16",
  "summarizeBy": "none",
  "modifiedTime": "2022-09-01T11:48:04.963333",
  "structureModifiedTime": "2022-06-24T20:18:07.96",
  "refreshedTime": "2022-09-01T11:48:04.963333",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:07.18",
    "refreshedTime": "2022-09-01T11:48:07.18"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-06-24T20:18:08.693333"
    },
    {
      "name": "PBI_ChangedProperties",
      "value": "[\"IsHidden\"]",
      "modifiedTime": "2022-06-29T17:48:22.866667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "é_prospect?",
  "dataType": "string",
  "isDataTypeInferred": true,
  "expression": "if('WIT Engajados Vendas e Não Vendas'[MODALIDADE NOVO] = \"PROSPECT\", \"Sim\",blank())",
  "lineageTag": "e4d9b42f-b82b-470d-ad80-7382887ca138",
  "summarizeBy": "none",
  "modifiedTime": "2022-09-01T11:48:11.956667",
  "structureModifiedTime": "2022-06-30T17:35:56.193333",
  "refreshedTime": "2022-09-01T11:48:11.956667",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:12.47",
    "refreshedTime": "2022-09-01T11:48:12.47"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-06-30T17:35:56.846667"
    }
  ]
},
    {
  "type": "calculated",
  "name": "indice_trans",
  "dataType": "string",
  "isDataTypeInferred": true,
  "expression": "'WIT Engajados Vendas e Não Vendas'[id_operation] & 'WIT Engajados Vendas e Não Vendas'[id_ticket]",
  "lineageTag": "92515f11-80b4-4221-a6cb-881eb79eee18",
  "summarizeBy": "none",
  "modifiedTime": "2022-09-01T11:48:18.18",
  "structureModifiedTime": "2022-07-05T17:46:30.44",
  "refreshedTime": "2022-09-01T11:48:18.18",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:48:32.96",
    "refreshedTime": "2022-09-01T11:48:32.96"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-07-05T17:46:31.183333"
    }
  ]
},
    {
  "type": "calculated",
  "name": "last_interaction",
  "dataType": "string",
  "isDataTypeInferred": true,
  "expression": "IF(LOOKUPVALUE(last_interaction[_id_ticket_data],last_interaction[_id_ticket_data],'WIT Engajados Vendas e Não Vendas'[_id_data] ) = BLANK(),\n                        BLANK(),\n                        \"Última Interação\"\n)",
  "lineageTag": "0e49c092-aaaf-4f6d-941c-4adb9e8e4f9e",
  "summarizeBy": "none",
  "modifiedTime": "2022-09-01T11:49:11.476667",
  "structureModifiedTime": "2022-07-28T20:50:18.066667",
  "refreshedTime": "2022-09-01T11:49:11.476667",
  "attributeHierarchy": {
    "state": "ready",
    "modifiedTime": "2022-09-01T11:49:11.483333",
    "refreshedTime": "2022-09-01T11:49:11.483333"
  },
  "annotations": [
    {
      "name": "SummarizationSetBy",
      "value": "Automatic",
      "modifiedTime": "2022-07-28T20:50:20.35"
    }
  ]
}
  ]
}"""
